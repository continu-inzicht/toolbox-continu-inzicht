# %% [markdown]
# # Belastingen uit matroos

# %% [markdown]
# ## 1. Voorbeeld met CSV
# Lees de configuratie in:
#
# Dit leest een configuratie bestand `belasting_noos_matroos_config.yaml` in.
# ```yaml
# GlobalVariables:
#     rootdir: "data_sets"
#     moments: [-24,0,24,48]
#
#     LoadsMatroos:
#         website: "noos"
#         model: "observed"
#         parameters: ["waterlevel"]
#
# DataAdapter:
#     default_options:
#         csv:
#             sep: ","
#
#     BelastingLocaties:
#         type: csv
#         path: "belastingen_matroos.csv"
#     Waterstanden:
#         type: csv
#         path: "waterstanden.csv"
#
# ```

# %%
from pathlib import Path

from toolbox_continu_inzicht import Config

test_data_sets_path = Path.cwd() / "data_sets"
c = Config(config_path=test_data_sets_path / "loads_noos_matroos_config.yaml")
c.lees_config()

# %% [markdown]
# Zet de data adapter klaar en geef deze de configuratie mee

# %%
from toolbox_continu_inzicht import DataAdapter

data = DataAdapter(config=c)

# %% [markdown]
# Run de module met CSV

# %%
from toolbox_continu_inzicht.loads import LoadsMatroos

matroos_obs = LoadsMatroos(data_adapter=data)

# %%
matroos_obs.df_in

# %%
ds = matroos_obs.run(input="BelastingLocaties", output="Waterstanden")

# %%
df = matroos_obs.df_out

# %%
df
# Out:
#      measurement_location_id measurement_location_code  \
# 0                          1                  delfzijl
# 1                          1                  delfzijl
# 2                          1                  delfzijl
# 3                          1                  delfzijl
# 4                          1                  delfzijl
# ..                       ...                       ...
# 583                        2                 denhelder
# 584                        2                 denhelder
# 585                        2                 denhelder
# 586                        2                 denhelder
# 587                        2                 denhelder
#
#     measurement_location_description  parameter_id parameter_code  \
# 0                           Delfzijl          4724         WATHTE
# 1                           Delfzijl          4724         WATHTE
# 2                           Delfzijl          4724         WATHTE
# 3                           Delfzijl          4724         WATHTE
# 4                           Delfzijl          4724         WATHTE
# ..                               ...           ...            ...
# 583                       Den Helder          4724         WATHTE
# 584                       Den Helder          4724         WATHTE
# 585                       Den Helder          4724         WATHTE
# 586                       Den Helder          4724         WATHTE
# 587                       Den Helder          4724         WATHTE
#
#                     date_time unit  value   value_type
# 0   2024-11-10 10:00:00+00:00   cm -137.0       meting
# 1   2024-11-10 10:10:00+00:00   cm -143.0       meting
# 2   2024-11-10 10:20:00+00:00   cm -146.0       meting
# 3   2024-11-10 10:30:00+00:00   cm -147.0       meting
# 4   2024-11-10 10:40:00+00:00   cm -147.0       meting
# ..                        ...  ...    ...          ...
# 583 2024-11-11 09:40:00+00:00   cm    9.0       meting
# 584 2024-11-11 09:50:00+00:00   cm   16.0       meting
# 585 2024-11-11 10:00:00+00:00   cm   22.0       meting
# 586 2024-11-11 10:10:00+00:00   cm   30.0  verwachting
# 587 2024-11-11 10:20:00+00:00   cm   38.0  verwachting
#
# [588 rows x 9 columns]

# %%
df_plot = df[df["measurement_location_description"] == "Hoek van Holland"]

# %%
import numpy as np  # type: ignore

values_nan = df_plot[df_plot["value"] == -999].index
for val in values_nan:
    df_plot.loc[val, "value"] = np.nan
df_plot = df_plot.set_index("date_time")

# %%
df_plot[["value"]].plot()
# Out:
# <Axes: xlabel='date_time'>

# %% [markdown]
# ### Dit waren alleen metingen, herhaal nu met dataset met ook voorspellingen

# %% [markdown]
# Dit leest een configuratie bestand `belasting_noos_matroos_config_fcst.yaml` in.
# ```yaml
# GlobalVariables:
#     rootdir: "data_sets"
#     moments: [-24,0,24,48]
#
#     LoadsMatroos:
#         website: "noos"
#         model: "dcsm6_kf"
#         parameters: ["waterlevel"]
#
# DataAdapter:
#     default_options:
#         csv:
#             sep: ","
#
#     BelastingLocaties:
#         type: csv
#         path: "belastingen_matroos.csv"
#     Waterstanden:
#         type: csv
#         path: "waterstanden.csv"
#
# ```

# %%
test_data_sets_path = Path.cwd() / "data_sets"
c = Config(config_path=test_data_sets_path / "loads_noos_matroos_fcst_config.yaml")
c.lees_config()
data = DataAdapter(config=c)

matroos_fsct = LoadsMatroos(data_adapter=data)

# %%
matroos_fsct.run(input="BelastingLocaties", output="Waterstanden")

# %%
df_fcst = matroos_fsct.df_out
df_plot_fcst = df_fcst[
    df_fcst["measurement_location_description"] == "Hoek van Holland"
]
values_nan = df_plot_fcst[df_plot_fcst["value"] == 999].index
for val in values_nan:
    df_plot_fcst.loc[val, "value"] = np.nan
df_plot_fcst = df_plot_fcst.set_index("date_time")

# %%
df_plot_fcst[["value"]].plot()
# Out:
# <Axes: xlabel='date_time'>

# %% [markdown]
# ##### vergelijk de twee

# %%
ax = df_plot_fcst[["value"]].plot()
df_plot[["value"]].plot(ax=ax)
ax.legend(["dscm6", "observed"]);

# %% [markdown]
# #### werkt ook met vitaal.matroos.rws
# werkt alleen als je in de `.env` username & password mee geeft
# ```yaml
# vitaal_user: "..."
# vitaal_password: "..."
# ```
#
# en de website aanpassen
#
# ```yaml
# LoadsMatroos:
#         website: "vitaal"
#
#
# ```

# %%
test_data_sets_path = Path.cwd() / "data_sets"
c = Config(config_path=test_data_sets_path / "loads_vitaal_matroos_fcst_config.yaml")
c.lees_config()
data = DataAdapter(config=c)

vitaal_fsct = LoadsMatroos(data_adapter=data)

# %%
vitaal_fsct.run(input="BelastingLocaties", output="Waterstanden")

# %%
df_vitaal_fcst = vitaal_fsct.df_out
df_plot_vitaal = df_vitaal_fcst[
    df_vitaal_fcst["measurement_location_description"] == "Hoek van Holland"
]
values_nan = df_plot_vitaal[df_plot_vitaal["value"] == 999].index
for val in values_nan:
    df_plot_vitaal.loc[val, "value"] = np.nan
df_plot_vitaal = df_plot_vitaal.set_index("date_time")

# %% [markdown]
# in dit geval indentiek:

# %%
ax = df_plot_fcst[["value"]].plot()
df_plot_vitaal["value"].plot(ls="--", ax=ax)
# Out:
# <Axes: xlabel='date_time'>

# %%
from toolbox_continu_inzicht.loads import get_matroos_locations

# %%
gdf = get_matroos_locations(parameter="waterlevel", source="dcsm6_kf")

# %%
gdf
# Out:
#                           geometry measurement_location_id  \
# 0     POINT Z (3.81011 55.39894 0)                     511
# 1    POINT Z (-2.07333 57.14333 0)                      38
# 2     POINT Z (0.78556 57.26056 0)                     111
# 3        POINT Z (3.29 51.36278 0)                    2160
# 4     POINT Z (2.06556 56.39972 0)                      48
# ..                             ...                     ...
# 176   POINT Z (6.65388 53.56998 0)                    1879
# 177   POINT Z (6.79509 53.50673 0)                    1880
# 178   POINT Z (6.83702 53.48027 0)                    1881
# 179   POINT Z (7.00684 53.32695 0)                    1882
# 180   POINT Z (0.72333 51.51333 0)                    1059
#
#     measurement_location_code
# 0                        A121
# 1                    Aberdeen
# 2                    anasuria
# 3                    appelzak
# 4           Aukfield platform
# ..                        ...
# 176               Eemsboei 17
# 177               Eemsboei 27
# 178               Eemsboei 30
# 179               Eemsboei 51
# 180                  southend
#
# [181 rows x 3 columns]

# %%
from toolbox_continu_inzicht.loads.loads_matroos.get_matroos_locations import (
    get_matroos_models,
)

# %%
df = get_matroos_models()

# %%
df[["source_label"]]
# Out:
#               source_label
# 0                  bma2_05
# 1                  bma2_25
# 2                  bma2_50
# 3                  bma2_75
# 4                  bma2_95
# ..                     ...
# 178              wdij_wind
# 179          wind_dsc_wdij
# 180            zeedelta_v1
# 181              swan_zuno
# 182  waves_zwartemeer_fews
#
# [183 rows x 1 columns]
