# %%
from pathlib import Path

import pandas as pd

from toolbox_continu_inzicht import Config, DataAdapter

# %%
path = Path.cwd() / "data_sets"
config = Config(config_path=path / "profile_to_db.yaml")
config.lees_config()
data_adapter = DataAdapter(config=config)

# %%
lst = []
for key in list(data_adapter.config.data_adapters.keys())[1:]:
    if "file" in data_adapter.config.data_adapters[key]:
        lst.append(data_adapter.config.data_adapters[key]["file"])

# %%
data_adapter.config.data_adapters
# Out:
# {'default_options': {'csv': {'sep': ','}},
#  'slopes': {'type': 'csv', 'file': 'slopes_multiple.csv', 'sep': ','},
#  'profiles': {'type': 'csv', 'file': 'profiles_multiple.csv', 'sep': ','},
#  'bedlevel_fetch': {'type': 'csv',
#   'file': 'bedlevelfetch_multiple.csv',
#   'sep': ','},
#  'slopes_db': {'type': 'ci_postgresql_slopes',
#   'database': 'geoserver',
#   'schema': 'continuinzicht_demo_realtime'},
#  'profiles_db': {'type': 'ci_postgresql_profiles',
#   'database': 'geoserver',
#   'schema': 'continuinzicht_demo_realtime'},
#  'bedlevel_fetch_db': {'type': 'ci_postgresql_bedlevelfetch',
#   'database': 'geoserver',
#   'schema': 'continuinzicht_demo_realtime'},
#  'slopes_db_in': {'type': 'postgresql_database',
#   'database': 'geoserver',
#   'schema': 'continuinzicht_demo_realtime',
#   'table': 'slopes'},
#  'profiles_db_in': {'type': 'postgresql_database',
#   'database': 'geoserver',
#   'schema': 'continuinzicht_demo_realtime',
#   'table': 'profiles'},
#  'bedlevel_fetch_db_in': {'type': 'postgresql_database',
#   'database': 'geoserver',
#   'schema': 'continuinzicht_demo_realtime',
#   'table': 'bedlevelfetch'}}

# %%
print(lst[0])
df = pd.read_csv(path / lst[0])
# Out:
# slopes_multiple.csv

# %%
df
# Out:
#     section_id  slopetypeid      x      y  r  damheight
# 0           10            1 -10.94  11.10  1          0
# 1           10            1   0.00  14.81  1          0
# 2           11            1 -12.59  10.76  1          0
# 3           11            1   0.00  14.63  1          0
# 4           11            2 -68.82  10.00  1          0
# 5           11            2 -12.59  10.76  1          0
# 6           12            1 -10.17  10.72  1          0
# 7           12            1   0.00  14.33  1          0
# 8           12            2 -65.00  10.72  1          0
# 9           12            2 -10.17  10.72  1          0
# 10          13            1 -11.72  10.38  1          0
# 11          13            1   0.00  14.21  1          0
# 12          13            2 -65.26   9.95  1          0
# 13          13            2 -11.72  10.38  1          0
# 14          14            1 -11.91   9.89  1          0
# 15          14            1   0.00  13.93  1          0
# 16          14            2 -67.90   9.80  1          0
# 17          14            2 -11.91   9.89  1          0
# 18          17            1 -11.91   9.89  1          0
# 19          17            1   0.00  13.93  1          0
# 20          17            2 -67.90   9.80  1          0
# 21          17            2 -11.91   9.89  1          0
# 22          27            1 -11.72  10.38  1          0
# 23          27            1   0.00  14.21  1          0
# 24          27            2 -65.26   9.95  1          0
# 25          27            2 -11.72  10.38  1          0

# %%
### dit schrijft de data naar de database
data_adapter.output("slopes_db", df)

# %%
df_in = data_adapter.input("slopes_db_in")
df_in
# Out:
#     sectionid  slopetypeid      x      y  r  damheight
# 0          10            1 -10.94  11.10  1          0
# 1          10            1   0.00  14.81  1          0
# 2          11            1 -12.59  10.76  1          0
# 3          11            1   0.00  14.63  1          0
# 4          11            2 -68.82  10.00  1          0
# 5          11            2 -12.59  10.76  1          0
# 6          12            1 -10.17  10.72  1          0
# 7          12            1   0.00  14.33  1          0
# 8          12            2 -65.00  10.72  1          0
# 9          12            2 -10.17  10.72  1          0
# 10         13            1 -11.72  10.38  1          0
# 11         13            1   0.00  14.21  1          0
# 12         13            2 -65.26   9.95  1          0
# 13         13            2 -11.72  10.38  1          0
# 14         14            1 -11.91   9.89  1          0
# 15         14            1   0.00  13.93  1          0
# 16         14            2 -67.90   9.80  1          0
# 17         14            2 -11.91   9.89  1          0
# 18         17            1 -11.91   9.89  1          0
# 19         17            1   0.00  13.93  1          0
# 20         17            2 -67.90   9.80  1          0
# 21         17            2 -11.91   9.89  1          0
# 22         27            1 -11.72  10.38  1          0
# 23         27            1   0.00  14.21  1          0
# 24         27            2 -65.26   9.95  1          0
# 25         27            2 -11.72  10.38  1          0

# %%
print(lst[1])
df = pd.read_csv(path / lst[1])
# Out:
# profiles_multiple.csv

# %%
### dit schrijft de data naar de database
data_adapter.output("profiles_db", df)

# %%
df_in = data_adapter.input("profiles_db_in")
df_in
# Out:
#    id                      name  profileid  crestlevel  orientation  dam  \
# 0   4  47-1_dp061+082-dp063+043         10       14.81          124    0
# 1   5  47-1_dp071+050-dp072+098         11       14.63          167    0
# 2   6  47-1_dp081+067-dp083+038         12       14.32          130    0
# 3   7  47-1_dp090+009-dp091+055         13       14.21          133    0
# 4   8  47-1_dp095+076-dp098+023         14       13.93          127    0
# 5   9  47-1_dp095+076-dp098+069         17       13.93          129    0
# 6  10  47-1_dp095+076-dp098+081         27       13.93          158    0
#
#    damheight     qcr  windspeed  sectormin  sectorsize  closing_situation
# 0          0  closed         20      180.0        90.0                  0
# 1          0  closed         20      180.0        90.0                  0
# 2          0  closed         20      180.0        90.0                  0
# 3          0  closed         20      180.0        90.0                  0
# 4          0  closed         20      180.0        90.0                  0
# 5          0  closed         20      180.0        90.0                  0
# 6          0  closed         20      180.0        90.0                  0

# %%
print(lst[2])
df = pd.read_csv(path / lst[2])
# Out:
# bedlevelfetch_multiple.csv

# %%
df
# Out:
#      section_id  direction  bedlevel      fetch
# 0            10       22.5  10.89870   162.7780
# 1            10       45.0  10.59700   591.3760
# 2            10       67.5  10.20710   902.4140
# 3            10       90.0   9.85752  1195.6600
# 4            10      112.5   9.69969  1197.7300
# ..          ...        ...       ...        ...
# 107          27      270.0   9.97087   108.2760
# 108          27      292.5   9.99384    62.6993
# 109          27      315.0  10.02250    56.3628
# 110          27      337.5  10.06570    68.3298
# 111          27      360.0  10.07330   301.9890
#
# [112 rows x 4 columns]

# %%
### dit schrijft de data naar de database
data_adapter.output("bedlevel_fetch_db", df)

# %%
df_in = data_adapter.input("bedlevel_fetch_db_in")
df_in
# Out:
#      sectionid  direction  bedlevel      fetch
# 0           10       22.5  10.89870   162.7780
# 1           10       45.0  10.59700   591.3760
# 2           10       67.5  10.20710   902.4140
# 3           10       90.0   9.85752  1195.6600
# 4           10      112.5   9.69969  1197.7300
# ..         ...        ...       ...        ...
# 107         27      270.0   9.97087   108.2760
# 108         27      292.5   9.99384    62.6993
# 109         27      315.0  10.02250    56.3628
# 110         27      337.5  10.06570    68.3298
# 111         27      360.0  10.07330   301.9890
#
# [112 rows x 4 columns]
